# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as gp

# %%
data = pd.read_excel('datos argentina.xls')

# %%
indicadores= data['Indicator Name']
dict(indicadores ) #los datos para construir la piramida poblacional van de indice 25 a 64 inclusive

gdp = data.iloc[16:21]

inflation = data.iloc[23:25]
gdp
# Out:
#                                        Indicator Name          1960  \
# 16                            GDP (constant 2015 US$)  1.507978e+11
# 17                              GDP growth (annual %)           NaN
# 18                 GDP per capita (constant 2015 US$)  7.362534e+03
# 19                   GDP per capita growth (annual %)           NaN
# 20  GDP per capita, PPP (constant 2017 internation...           NaN
#
#             1961          1962          1963          1964          1965  \
# 16  1.589829e+11  1.576283e+11  1.492611e+11  1.643817e+11  1.817559e+11
# 17  5.427843e+00 -8.520215e-01 -5.308197e+00  1.013030e+01  1.056943e+01
# 18  7.637067e+03  7.451803e+03  6.945957e+03  7.532004e+03  8.202113e+03
# 19  3.728779e+00 -2.425843e+00 -6.788240e+00  8.437244e+00  8.896809e+00
# 20           NaN           NaN           NaN           NaN           NaN
#
#             1966          1967          1968  ...          2012          2013  \
# ...

# %%
fig, pan1 = plt.subplots( sharex=True, constrained_layout=True, figsize=(15,6))

pan2=pan1.twinx()

años=inflation.columns[1:-1]
inflation_x_year = inflation.iloc[0,1:-1]
inflation_cumulative = inflation.iloc[1,1:-1]

pan1.plot(años, inflation_x_year, color = 'red', label = 'inflacion por año')
pan2.plot(años, inflation_cumulative, color = 'green', label='inflacion acumulada')

pan1.set_ylabel('inflacion por año')
pan2.set_ylabel('inflacion acumulada')
pan1.set_xlabel('Año')
for tick in pan1.get_xticklabels():
    tick.set_rotation(45)

plt.show()

# %%
fig, pan1 = plt.subplots( sharex=True, constrained_layout=True, figsize=(15,6))

pan2=pan1.twinx()

años=inflation.columns[33:-1]
inflation_x_year2 = inflation.iloc[0,33:-1]
inflation_cumulative2 = inflation.iloc[1,33:-1]

pan1.plot(años, inflation_x_year2, color = 'red', label = 'inflacion por año')
pan2.plot(años, inflation_cumulative2, color = 'green', label='inflacion acumulada')

pan1.set_ylabel('inflacion por año')
pan2.set_ylabel('inflacion acumulada')
pan1.set_xlabel('Año')
for tick in pan1.get_xticklabels():
    tick.set_rotation(45)

plt.show()

# %%
gdp
# Out:
#                                        Indicator Name          1960  \
# 16                            GDP (constant 2015 US$)  1.507978e+11
# 17                              GDP growth (annual %)           NaN
# 18                 GDP per capita (constant 2015 US$)  7.362534e+03
# 19                   GDP per capita growth (annual %)           NaN
# 20  GDP per capita, PPP (constant 2017 internation...           NaN
#
#             1961          1962          1963          1964          1965  \
# 16  1.589829e+11  1.576283e+11  1.492611e+11  1.643817e+11  1.817559e+11
# 17  5.427843e+00 -8.520215e-01 -5.308197e+00  1.013030e+01  1.056943e+01
# 18  7.637067e+03  7.451803e+03  6.945957e+03  7.532004e+03  8.202113e+03
# 19  3.728779e+00 -2.425843e+00 -6.788240e+00  8.437244e+00  8.896809e+00
# 20           NaN           NaN           NaN           NaN           NaN
#
#             1966          1967          1968  ...          2012          2013  \
# ...

# %%
fig, pan1 = plt.subplots( sharex=True, constrained_layout=True, figsize=(12,6))

pan2=pan1.twinx()
pan3=pan1.twinx()

años=gdp.columns[1:-1]
gdp_x_year = gdp.iloc[0,1:-1]
gdppp = gdp.iloc[2,1:-1]
gdp_growth = gdp.iloc[1,1:-1]

pan1.plot(años, gdp_x_year, color = 'red', label = 'PBI')
pan2.plot(años, gdppp, color = 'green', label='PBI per capita')
pan3.plot(años, gdp_growth, color = 'blue', label='crecimieento del PBI (%)')

pan1.set_ylabel('PBI (Millones de U$S)')
pan2.set_ylabel('PBI per capita (U$S)')
pan3.set_ylabel('crecimiento del PBI (%)')
pan1.set_xlabel('Año')
fig.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
for tick in pan1.get_xticklabels():
    tick.set_rotation(90)
    
pan3.spines["right"].set_position(("axes", 1.1))

plt.show()
